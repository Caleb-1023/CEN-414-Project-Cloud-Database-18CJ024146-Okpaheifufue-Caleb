# %% [markdown]
# # OKPAHEIFUFUE CALEB
# # 18CJ024146
# # COMPUTER ENGINEERING
# # 400 LEVEL
# # CEN 414 PROJECT
# # TOPIC: WOMEN'S SHARE OF PARLIAMENTARY SEATS IN SINGLE OR LOWER CHAMBER IN AFRICAN NATIONS

# %% [markdown]
# PROJECT REPORT

# %%
import matplotlib
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math
from statistics import mean, variance, stdev, mode, median
import seaborn as sns
from matplotlib import style
sns.set()


data_set = pd.read_csv('UNdata_Export.csv')
data_set=data_set.set_index('AFRICAN NATIONS')
data_set
# Out:
#                                   2010  2011  2012  2013  2014  2015  2016  \
# AFRICAN NATIONS
# Algeria                            7.7   8.0  31.6  31.6  31.6  31.6  32.5
# Angola                            38.6  38.2  34.1  34.1  34.1  34.1  32.0
# Benin                             10.8   8.4   8.4   8.4   8.4   8.4   9.6
# Botswana                           7.9   7.9   7.9   7.9   7.9   7.9   6.3
# Burkina Faso                      15.3  15.3  15.7  15.7  15.7  15.7  14.9
# Burundi                           32.1  30.5  30.5  30.5  30.5  30.5  28.6
# Cameroon                          13.9  13.9  13.9  31.1  31.1  31.1  34.8
# Cape Verde                        18.1  20.8  20.8  20.8  20.8  20.8  21.9
# Central African Republic           9.6  12.5  12.5  12.5  12.5  12.5  15.3
# Chad                               5.2  12.8  14.9  14.9  14.9  14.9  12.2
# Comoros                            3.0   3.0   3.0   3.0   3.0   3.0   4.0
# ...

# %%
data_set
# Out:
#                      AFRICAN NATIONS  2010  2011  2012  2013  2014  2015  \
# 0                            Algeria   7.7   8.0  31.6  31.6  31.6  31.6
# 1                             Angola  38.6  38.2  34.1  34.1  34.1  34.1
# 2                              Benin  10.8   8.4   8.4   8.4   8.4   8.4
# 3                           Botswana   7.9   7.9   7.9   7.9   7.9   7.9
# 4                       Burkina Faso  15.3  15.3  15.7  15.7  15.7  15.7
# 5                            Burundi  32.1  30.5  30.5  30.5  30.5  30.5
# 6                           Cameroon  13.9  13.9  13.9  31.1  31.1  31.1
# 7                         Cape Verde  18.1  20.8  20.8  20.8  20.8  20.8
# 8           Central African Republic   9.6  12.5  12.5  12.5  12.5  12.5
# 9                               Chad   5.2  12.8  14.9  14.9  14.9  14.9
# 10                           Comoros   3.0   3.0   3.0   3.0   3.0   3.0
# 11                             Congo   7.3   7.3   7.4   7.4   7.4   7.4
# ...

# %%
#Bar chart plot for each nation per year
for d_year in range(2010, 2019):
    data_set.plot.bar(y=str(d_year), figsize=(11,11), title=str(d_year))
    plt.figure(figsize=(50,50))

# %%
years = ['2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019']

# %%
#Mean share per year
data_set[years].mean()

x = years
y = data_set[years].mean()

plt.bar(x,y)
plt.show()

data_set[years].mean()
# Out:
# 2010    16.023077
# 2011    16.705769
# 2012    18.434615
# 2013    19.405769
# 2014    19.405769
# 2015    19.405769
# 2016    19.288462
# 2017    19.288462
# 2018    19.288462
# 2019    19.288462
# dtype: float64

# %%
#Standard Deviation of share per year
data_set[years].std()

x = years
y = data_set[years].std()

plt.bar(x,y)
plt.show()

data_set[years].std()
# Out:
# 2010    11.470706
# 2011    11.678645
# 2012    11.496647
# 2013    12.172299
# 2014    12.172299
# 2015    12.172299
# 2016    11.988976
# 2017    11.988976
# 2018    11.988976
# 2019    11.988976
# dtype: float64

# %%
#Variance of share per year
data_set[years].var()
# Out:
# 2010    131.577104
# 2011    136.390750
# 2012    132.172896
# 2013    148.164868
# 2014    148.164868
# 2015    148.164868
# 2016    143.735551
# 2017    143.735551
# 2018    143.735551
# 2019    143.735551
# dtype: float64

# %%
#Mode of share per year
data_set[years].mode
# Out:
# <bound method DataFrame.mode of                                   2010  2011  2012  2013  2014  2015  2016  \
# AFRICAN NATIONS
# Algeria                            7.7   8.0  31.6  31.6  31.6  31.6  32.5
# Angola                            38.6  38.2  34.1  34.1  34.1  34.1  32.0
# Benin                             10.8   8.4   8.4   8.4   8.4   8.4   9.6
# Botswana                           7.9   7.9   7.9   7.9   7.9   7.9   6.3
# Burkina Faso                      15.3  15.3  15.7  15.7  15.7  15.7  14.9
# Burundi                           32.1  30.5  30.5  30.5  30.5  30.5  28.6
# Cameroon                          13.9  13.9  13.9  31.1  31.1  31.1  34.8
# Cape Verde                        18.1  20.8  20.8  20.8  20.8  20.8  21.9
# Central African Republic           9.6  12.5  12.5  12.5  12.5  12.5  15.3
# Chad                               5.2  12.8  14.9  14.9  14.9  14.9  12.2
# Comoros                            3.0   3.0   3.0   3.0   3.0   3.0   4.0
# ...

# %%
#Stacked bar chart 
data_set.groupby('AFRICAN NATIONS').median().plot.bar(stacked=True)

plt.title('Median')
# Out:
# Text(0.5, 1.0, 'Median')

# %%
#Median of share per year
data_set[years].median
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.median of                                   2010  2011  2012  2013  2014  2015  2016  \
# AFRICAN NATIONS
# Algeria                            7.7   8.0  31.6  31.6  31.6  31.6  32.5
# Angola                            38.6  38.2  34.1  34.1  34.1  34.1  32.0
# Benin                             10.8   8.4   8.4   8.4   8.4   8.4   9.6
# Botswana                           7.9   7.9   7.9   7.9   7.9   7.9   6.3
# Burkina Faso                      15.3  15.3  15.7  15.7  15.7  15.7  14.9
# Burundi                           32.1  30.5  30.5  30.5  30.5  30.5  28.6
# Cameroon                          13.9  13.9  13.9  31.1  31.1  31.1  34.8
# Cape Verde                        18.1  20.8  20.8  20.8  20.8  20.8  21.9
# Central African Republic           9.6  12.5  12.5  12.5  12.5  12.5  15.3
# Chad                               5.2  12.8  14.9  14.9  14.9  14.9  12.2
# ...

# %%
iqrs =[]
for year in range(2010,2019):
    iqrs.append(data_set[str(year)].quantile(0.75) - data_set[str(year)].quantile(0.25))
    
    
    
plt.ylabel("Interquatile range")
plt.xlabel("Years")
plt.title("INTERQUATILE RANGE FIXED SUBSCRIPTION")
plt.plot(range(2010,2019),iqrs)
