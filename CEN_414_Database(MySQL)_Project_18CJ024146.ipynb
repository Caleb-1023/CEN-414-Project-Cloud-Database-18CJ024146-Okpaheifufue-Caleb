# %%
import mysql.connector as sql

mydb = sql.connect(
    host="127.0.0.1",
    user="root",
    port=3306,
    passwd="kAlemkoko)6",
    database = 'cen_414db'

)

print(mydb)

# %%
import pandas as pd
    
DATA = pd.read_sql_query('SHOW TABLES FROM cen_414db', mydb)
DATA
# Out:
#   Tables_in_cen_414db
# 0       cen_414_table

# %%
tables = DATA['Tables_in_cen_414db']

# %%
for table_name in tables:
    OUTPUT = pd.read_sql_query('DESCRIBE {}'.format(table_name), mydb)
    print(table_name)
    print(OUTPUT)
# Out:
# cen_414_table
#                  Field       Type Null Key Default Extra
# 0              NATIONS    b'text'  YES        None
# 1                 Year     b'int'  YES        None
# 2                 Code    b'text'  YES        None
# 3  Women in Parliament  b'double'  YES        None

# %%
DATA = 'SELECT * FROM cen_414_table'

# %%
df = pd.read_sql_query(DATA , mydb)

# %%
df
# Out:
#       NATIONS  Year Code  Women in Parliament
# 0     Algeria  2010  ALG                  7.7
# 1     Algeria  2011  ALG                  8.0
# 2     Algeria  2012  ALG                 31.6
# 3     Algeria  2013  ALG                 31.6
# 4     Algeria  2014  ALG                 31.6
# ..        ...   ...  ...                  ...
# 515  Zimbabwe  2015  ZIM                 31.5
# 516  Zimbabwe  2016  ZIM                 29.8
# 517  Zimbabwe  2017  ZIM                 29.8
# 518  Zimbabwe  2018  ZIM                 29.8
# 519  Zimbabwe  2019  ZIM                 29.8
#
# [520 rows x 4 columns]

# %%
df.groupby(['Year']) ['Code'].count()
# Out:
# Year
# 2010    52
# 2011    52
# 2012    52
# 2013    52
# 2014    52
# 2015    52
# 2016    52
# 2017    52
# 2018    52
# 2019    52
# Name: Code, dtype: int64

# %%
query = 'SELECT * FROM cen_414_table  WHERE Year = 2019'

# %%
df = pd.read_sql_query(query , mydb)

# %%
df
# Out:
#                              NATIONS  Year Code  Women in Parliament
# 0                            Algeria  2019  ALG                 32.5
# 1                             Angola  2019  ANG                 10.8
# 2                              Benin  2019  BEN                  8.4
# 3                           Botswana  2019  BOT                  6.3
# 4                       Burkina Faso  2019  BKF                 14.9
# 5                            Burundi  2019  BUR                 28.6
# 6                           Cameroon  2019  CAM                 34.8
# 7                         Cape Verde  2019  CAP                 21.9
# 8           Central African Republic  2019  CAR                 15.3
# 9                               Chad  2019  CHD                 12.2
# 10                           Comoros  2019  COM                  4.0
# 11                             Congo  2019  CON                  8.6
# 12                    C̫te d'Ivoire  2019  COT                 13.4
# ...

# %%
query = 'SELECT * FROM cen_414_table  WHERE Code = "NGR"'
df = pd.read_sql_query(query , mydb)
df
# Out:
#    NATIONS  Year Code  Women in Parliament
# 0  Nigeria  2010  NGR                  7.0
# 1  Nigeria  2011  NGR                  6.8
# 2  Nigeria  2012  NGR                  6.7
# 3  Nigeria  2013  NGR                  6.7
# 4  Nigeria  2014  NGR                  6.7
# 5  Nigeria  2015  NGR                  6.7
# 6  Nigeria  2016  NGR                  7.2
# 7  Nigeria  2017  NGR                  7.2
# 8  Nigeria  2018  NGR                  7.2
# 9  Nigeria  2019  NGR                  7.2
